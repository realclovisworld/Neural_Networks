# %% [markdown]
# <a href="https://colab.research.google.com/github/realclovisworld/Neural_Networks/blob/main/Training_NN_notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Training NN
#
# (1). Define the problem
#
# (2). Collect and preparre the data
#
#     a) Data collection
#     b) Data preprocessing
#         i).handle missing values
#         ii).normalize or standardize
#         iii).encode categorical variables
#         iv).split the dataset
#
#
# (3). Choose a neural network architeture
#
#     ie. CNN, RNN,Feedforward,etc
#
# (4) initialize weights
#
# (5). Define the loss function
#
# (6). choose optimizer
#
# (7). Train the model
#
#      a).forward pass
#      b).calculate loss
#      c).backward pass
#      d).update weights
#
# (8). monitor training
#
# (9) evaluate the model
#
# (10). fine tune and hyperparameter optimization
#
# (11) deployment
