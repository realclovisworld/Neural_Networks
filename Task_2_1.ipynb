# %% [markdown]
# <a href="https://colab.research.google.com/github/realclovisworld/Neural_Networks/blob/main/Task_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import img_to_array,load_img

# %%
#Load your trained model

model = tf.keras.models.load_model('DFF-Model.keras')

# %%
#Path to the unseen image

image_path = '/content/image6.png'

# %%
img = load_img(image_path, color_mode='grayscale', target_size=(28, 28))

# %%
img_array = img_to_array(img)

# %%
img_array = img_array / 255.0

# %%
img_array = np.expand_dims(img_array, axis=0)

# %%
#Perform predictions

predictions = model.predict(img_array)
prediction_digits = np.argmax(predictions[0])
confidence = np.max(predictions[0]) * 100
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_748/3378901316.py in <cell line: 0>()
#       1 #Perform predictions
#       2
# ----> 3 predictions = model.predict(img_array)
#       4 prediction_digits = np.argmax(predictions[0])
#       5 confidence = np.max(predictions[0]) * 100
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.12/dist-packages/keras/src/models/functional.py in _adjust_input_rank(self, flat_inputs)
#     276             flat_paths_and_inputs = tree.flatten_with_path(self._inputs_struct)
# ...
