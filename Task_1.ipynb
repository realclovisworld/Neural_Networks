# %% [markdown]
# <a href="https://colab.research.google.com/github/realclovisworld/Neural_Networks/blob/main/Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Task 1:**
#
#   **(QN)** Build an Artificial Neural Network by implementing the backpropagation algorithm and test the same using appropriate datasets. vary the activation functions used and compare results

# %% [markdown]
# # **STEPS**
#
#
# 1. Import python liblaries for building and training the ANN
# 2. Load the Iris dataset into testing and training
# 3. Define the architecture of the Artificial Neural Network (ANN) model using Keras's Sequential API.
# 4. Apply activation function(sigmoid)
# 5. Compile the model
# 6. Get the model summary
# 7. Train the model
# 8. Evaluate the model on the test dataset
# 9. Print the model loss and Accuracy scores

# %%
#Import necessary python liblaries
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.optimizers import SGD
import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn.model_selection import train_test_split

#Load the iris dataset
iris = datasets.load_iris()
X,y = datasets.load_iris(return_X_y = True)

#Test train split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size =0.4)

#Define ANN  Architecture
model = Sequential()
model.add(Dense(2, input_shape=(4,)))
model.add(Activation('sigmoid'))
model.add(Dense(1))
model.add(Activation('sigmoid'))

#compile the model
sgd = SGD(learning_rate=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss = 'mean_squared_error', optimizer = 'sgd', metrics=['accuracy'])

model.summary()

#train the model
model.fit(X_train, y_train, epochs=100)

#Model evaluatiton
score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.13/dist-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 2)              │            10 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %% [markdown]
# # **Exercise.**
#
# 1. Note down the accuracies for the following set of experiments on the given ANN and compile the results.
# Do the required modifications needed. Take training data percentage 30%, test data percentage 70%
#
# 2. NN model with 2 hidden layers
#
#     * iris dataset
#
#     * Number of epochs=100,
#
#     * check accuracy using activation function sigmoid, ReLu, Tanh
#     * check accuracy using optimizer sgd, ADAM
#     * check accuracy by varying learning rate in sgd as 0.001, 0.0005, 0.5
#     * check accuracy using loss mean squared error, categorical cross entropy.

# %% [markdown]
# # **Using activation function (ReLu) , optimizer as (sgd) and loss as (MSE)**

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
import numpy as np
import pandas as pd
from sklearn import datasets
from keras.optimizers import SGD
from sklearn.model_selection import train_test_split

iris = datasets.load_iris()
X,y = datasets.load_iris(return_X_y = True)
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size =0.7)

model = Sequential()
model.add(Dense(2, input_shape=(4,)))
model.add(Activation('relu'))
model.add(Dense(1))
model.add(Activation('relu'))

sgd = SGD(learning_rate=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss = 'mean_squared_error', optimizer = 'sgd', metrics=['accuracy'])

model.summary()

model.fit(X_train, y_train, epochs=100)

score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# %% [markdown]
# # Using Activation function (Tanh) and optimizer as (sgd)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
import numpy as np
import pandas as pd
from sklearn import datasets
from keras.optimizers import SGD
from sklearn.model_selection import train_test_split


iris = datasets.load_iris()
X,y = datasets.load_iris(return_X_y = True)
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size =0.7)

model = Sequential()
model.add(Dense(2, input_shape=(4,)))
model.add(Activation('tanh'))
model.add(Dense(1))
model.add(Activation('tanh'))

sgd = SGD(learning_rate=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss = 'mean_squared_error', optimizer = 'sgd', metrics=['accuracy'])

model.summary

model.fit(X_train, y_train, epochs=100)

score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# %% [markdown]
# # Using Activation function (sigmoid) and optimizer (ADAM)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
import numpy as np
import pandas as pd
from sklearn import datasets
from keras.optimizers import SGD, Adam
from sklearn.model_selection import train_test_split


iris = datasets.load_iris()
X,y = datasets.load_iris(return_X_y = True)
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size =0.7)

model = Sequential()
model.add(Dense(2, input_shape=(4,)))
model.add(Activation('sigmoid'))
model.add(Dense(1))
model.add(Activation('sigmoid'))


adam = Adam(learning_rate=0.001)
model.compile(loss = 'mean_squared_error', optimizer = 'adam', metrics=['accuracy'])

model.summary()

model.fit(X_train, y_train, epochs=100)

score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# %% [markdown]
# # Using activation function (relu) and optimizer (adam)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
import numpy as np
import pandas as pd
from sklearn import datasets
from keras.optimizers import SGD, Adam
from sklearn.model_selection import train_test_split


iris = datasets.load_iris()
X,y = datasets.load_iris(return_X_y = True)
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size =0.7)

model = Sequential()
model.add(Dense(2, input_shape=(4,)))
model.add(Activation('relu'))
model.add(Dense(1))
model.add(Activation('relu'))


adam = Adam(learning_rate=0.001)
model.compile(loss = 'mean_squared_error', optimizer = 'adam', metrics=['accuracy'])

model.summary()

model.fit(X_train, y_train, epochs=100)

score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# %% [markdown]
# # using activation function (tanh) and optimizer (adam)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
import numpy as np
import pandas as pd
from sklearn import datasets
from keras.optimizers import SGD, Adam
from sklearn.model_selection import train_test_split


iris = datasets.load_iris()
X,y = datasets.load_iris(return_X_y = True)
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size =0.7)

model = Sequential()
model.add(Dense(2, input_shape=(4,)))
model.add(Activation('tanh'))
model.add(Dense(1))
model.add(Activation('tanh'))


adam = Adam(learning_rate=0.001)
model.compile(loss = 'mean_squared_error', optimizer = 'adam', metrics=['accuracy'])

model.summary()

model.fit(X_train, y_train, epochs=100)

score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# %% [markdown]
# # check accuracy by varying learning rate in sgd as 0.001, 0.0005, 0.5

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
import numpy as np
import pandas as pd
from sklearn import datasets
from keras.optimizers import SGD
from sklearn.model_selection import train_test_split


iris = datasets.load_iris()
X,y = datasets.load_iris(return_X_y = True)
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size =0.7)

model = Sequential()
model.add(Dense(2, input_shape=(4,)))
model.add(Activation('tanh'))
model.add(Dense(1))
model.add(Activation('tanh'))

sgd = SGD(learning_rate=0.5, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss = 'mean_squared_error', optimizer = 'sgd', metrics=['accuracy'])

model.summary

model.fit(X_train, y_train, epochs=100)

score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# %% [markdown]
# for 0.001 using sgd and activation function(tanh) = Test loss: 0.3627234101295471
# Test accuracy: 0.6761904954910278
#
# for 0.005 using sgd and activation function(tanh) = Test loss: 0.3314005136489868
# Test accuracy: 0.7047619223594666
#
# for 0.5 using sgd and activation function(tanh) = Test loss: 0.36123403906822205
# Test accuracy: 0.6761904954910278
